# %% [markdown]
# ## Optimizing f(x) subject to constraint g(x) with penalty functions

# %%
import numpy as np

def f(x):
    """
    Objective function to minimize
    """
    return (6*x - 2)**2 * np.sin(12 * x - 4)

def g(x):
    """
    Constraint on Objective function
    """
    return np.sin(10*x)

def neg_g(x):
    return -np.sin(10*x)

def phi_death(x, f, g, inf=20):
    """
    Death Penalty
    """
    if g(x) <= 0:
        return f(x)
    else:
        return inf

def s(x, g, r=20, beta=1):
    """
    Static Penalty
    """
    return r * np.max([0, g(x)])**beta

def phi_static(x, f, g, s, r=20, beta=1):
    """
    Modified func with static phi
    """
    return f(x) + s(x, g, r, beta)

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
plt.ion()

# %%
x = np.linspace(0,1,1000)
yf = f(x)
yg = g(x)
yd = np.array([phi_death(i, f, g) for i in x])
ys = np.array([phi_static(i, f, g, s) for i in x])
cut_off = 0

# %%
plt.figure()
plt.plot(x, yf, label="True Function")
plt.plot(x, yg, label="Constraint Function")
plt.plot(x, yd, label="Death Penalty")
plt.plot(x, ys, label="Static Penalty")
plt.axhline(cut_off, color="black", ls="dotted")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25),
          ncol=2, fancybox=True, shadow=True)

# %% [markdown]
# ## Location of minimum

# %%
x_star_ind = np.argmin(yf)
print(x[x_star_ind], yf[x_star_ind])
# Out:
# 0.7567567567567568 -6.020610973593629

# %%
plt.figure()
plt.plot(x, yf)
plt.plot(x, yg)
plt.plot(x, yd)
plt.plot(x, ys)
plt.axhline(cut_off, color="black", ls="dotted")
plt.axvline(x[x_star_ind], color="black", ls="dashed")

# %% [markdown]
# ## Minimum with death penalty

# %% [markdown]
# From the Figure, it is clear that $x_g^*, x_d^*$ and $x_s^*$ are the same.

# %%
xg_star_ind = np.argmin(yd)
print(x[xg_star_ind], yf[xg_star_ind])
# Out:
# 0.6276276276276276 -1.1852241199178717

# %%
plt.figure()
plt.plot(x, yf)
plt.plot(x, yg)
plt.plot(x, yd)
plt.plot(x, ys)
plt.axhline(cut_off, color="black", ls="dotted")
plt.axvline(x[x_star_ind], color="black", ls="dashed")
plt.axvline(x[xg_star_ind], color="red", ls="dashed")

# %% [markdown]
# Imposing the constraint has changed the location of the minimum.

# %% [markdown]
# ## If static penalty is subtracted instead of added:

# %%
def phi_static_prime(x, f, g, s, r=20, beta=1):
    return f(x) - s(x, g, r, beta)
ysp = np.array([phi_static_prime(i, f, g, s) for i in x])

# %%
plt.figure()
plt.plot(x, yf)
plt.plot(x, yg)
plt.plot(x, ysp)
plt.axhline(cut_off, color="black", ls="dotted")

# %% [markdown]
# The implication is that this penalty term now misleading if I am minimizing as the location of the minimum clearly changes and goes into the infeasible space.
#
# However, this can be useful in case of maximizing the function. As clearly the local maximum in the feasible regions remain unaltered this way.

# %% [markdown]
# ## Modifying constraint
#
# Multiply $-1$ on both sides and transform the constraint to: $-g(x) = -sin(x) \leq 0$, and then use the standard forms of penalty functions. Plotting the function and performing appropriate analyses should reveal that the optimal solution has changed as the feasible space has changed.

# %%
x = np.linspace(0,1,1000)
yf = f(x)
yg_n = neg_g(x)
yd_n = np.array([phi_death(i, f, neg_g) for i in x])
ys_n = np.array([phi_static(i, f, neg_g, s) for i in x])
cut_off = 0
# new optimal solution
xg_star_ind_n = np.argmin(yd_n)

# %%
plt.figure()
plt.plot(x, yf)
plt.plot(x, yg_n)
plt.plot(x, yd_n)
plt.plot(x, ys_n)
plt.axhline(cut_off, color="black", ls="dotted")
plt.axvline(x[xg_star_ind_n], color="red", ls="dashed")
